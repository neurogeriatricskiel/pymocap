# %%
import pandas as pd
import os
import numpy as np

# %%
data_dir = "Z:\\Keep Control\\Output\\lab dataset\\_issues"
file_name = "2021-01-11_overview_participants.xlsx"
sheet_name = "demographics"

# %%
df = pd.read_excel(os.path.join(data_dir, file_name), sheet_name=sheet_name, header=0)
df.head()
# Out:
#    participant_id  gender  age  height  weight participant_type  \
# 0               1       1   25   177.0    74.0               YA
# 1               2       0   34   182.5    93.0               YA
# 2               3       0   32   195.0   103.0               YA
# 3               4       0   32   172.0    67.9               YA
# 4               5       0   26   174.0    66.8               YA
#
#    participant_type__YA  participant_type__OA  participant_type__PD  \
# 0                     1                     0                     0
# 1                     1                     0                     0
# 2                     1                     0                     0
# 3                     1                     0                     0
# 4                     1                     0                     0
#
#    participant_type__stroke  ...  participant_type__LBP  \
# 0                         0  ...                      0
# ...

# %%
df[df["participant_type"]=="YA"]["age"].std()
# Out:
# 9.399939300807153

# %%
df["participant_type"].unique()
# Out:
# array(['YA', 'others', 'PD', 'OA', 'stroke', 'MS', 'PNP', 'LBP', 'TIA'],
#       dtype=object)
